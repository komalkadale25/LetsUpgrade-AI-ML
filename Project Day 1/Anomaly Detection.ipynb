# %%
import os
import sys
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from scipy.io import loadmat

# %% [markdown]
# # Import Pyod and the methods

# %%
from pyod.models.pca import PCA
from pyod.models.mcd import MCD
from pyod.models.ocsvm import OCSVM
from pyod.models.lof import LOF
from pyod.models.cblof import CBLOF
from pyod.models.knn import KNN
from pyod.models.hbos import HBOS
from pyod.models.abod import ABOD
from pyod.models.iforest import IForest
from pyod.models.feature_bagging import FeatureBagging
# Out:
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Import Metrics Package

# %%
from pyod.utils.utility import standardizer
from pyod.utils.utility import precision_n_scores
from sklearn.metrics import roc_auc_score

# %%
mat_file_list=['arrhythmia.mat','cardio.mat','glass.mat','ionosphere.mat','letter.mat','lympho.mat','mnist.mat','musk.mat','optdigits.mat','pendigits.mat','pima.mat','satellite.mat','satimage-2.mat','shuttle.mat','shuttle.mat','vertebral.mat','vowels.mat','wbc.mat']

# %%
mat_file_list
# Out:
# ['arrhythmia.mat',
#  'cardio.mat',
#  'glass.mat',
#  'ionosphere.mat',
#  'letter.mat',
#  'lympho.mat',
#  'mnist.mat',
#  'musk.mat',
#  'optdigits.mat',
#  'pendigits.mat',
#  'pima.mat',
#  'satellite.mat',
#  'satimage-2.mat',
#  'shuttle.mat',
#  'shuttle.mat',
#  'vertebral.mat',
#  'vowels.mat',
#  'wbc.mat']

# %% [markdown]
# # Loading mat file

# %%
data=loadmat("mat_files/cardio.mat")

# %%
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X': array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#          -0.28978574, -0.49329397],
#         [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#          -0.25638541, -0.49329397],
#         [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#          -0.25638541,  1.14001753],
#         ...,
#         [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#           0.24461959, -0.49329397],
#         [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#           0.14441859, -0.49329397],
#         [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#           3.58465295, -0.49329397]]),
#  'y': array([[0.],
#         [0.],
#         [0.],
#         ...,
#         [1.],
#         [1.],
#         [1.]])}

# %%
len(data)
# Out:
# 5

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X', 'y'])

# %%
data.values()
# Out:
# dict_values([b'MATLAB 5.0 MAT-file, written by Octave 3.8.0, 2014-12-18 10:48:09 UTC', '1.0', [], array([[ 0.00491231,  0.69319077, -0.20364049, ...,  0.23149795,
#         -0.28978574, -0.49329397],
#        [ 0.11072935, -0.07990259, -0.20364049, ...,  0.09356344,
#         -0.25638541, -0.49329397],
#        [ 0.21654639, -0.27244466, -0.20364049, ...,  0.02459619,
#         -0.25638541,  1.14001753],
#        ...,
#        [-0.41835583, -0.91998844, -0.16463485, ..., -1.49268341,
#          0.24461959, -0.49329397],
#        [-0.41835583, -0.91998844, -0.15093411, ..., -1.42371616,
#          0.14441859, -0.49329397],
#        [-0.41835583, -0.91998844, -0.20364049, ..., -1.28578165,
#          3.58465295, -0.49329397]]), array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [1.],
#        [1.],
#        [1.]])])

# %%
df_columns=['Data','#Sample','#Dimensions','Outlier Perc','PCA','MCD','OCSVM','LOF','CBLOF','KNN','HBOS','ABOD','IFOREST','FEATUREBAGGING']

# %% [markdown]
# # Precision Time and Roc evolution tables creation

# %%
roc_df=pd.DataFrame(columns=df_columns)
prn_df=pd.DataFrame(columns=df_columns)
time_df=pd.DataFrame(columns=df_columns)
print(roc_df,prn_df,time_df)
# Out:
# Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: [] Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: [] Empty DataFrame
# Columns: [Data, #Sample, #Dimensions, Outlier Perc, PCA, MCD, OCSVM, LOF, CBLOF, KNN, HBOS, ABOD, IFOREST, FEATUREBAGGING]
# Index: []

# %% [markdown]
# ## Input(Independent) Feature shape in mat file format

# %%
type(data['X']),data['X'].shape
# Out:
# (numpy.ndarray, (1831, 21))

# %% [markdown]
# ##  Dependent/ Target/ Output Feature shape in mat file format

# %%
type(data['y']),data['y'].shape
# Out:
# (numpy.ndarray, (1831, 1))

# %% [markdown]
# # Exploring Mat files

# %%
from time import time
random_state = np.random.RandomState(42)

for mat_file in mat_file_list:
   print("\n... Processing", mat_file, '...')
   mat = loadmat(os.path.join('mat_files', mat_file))

   X = mat['X']
   y = mat['y'].ravel()
   outliers_fraction = np.count_nonzero(y) / len(y)
   outliers_percentage = round(outliers_fraction * 100, ndigits=4)

   # construct containers for saving results
   roc_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
   prn_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]
   time_list = [mat_file[:-4], X.shape[0], X.shape[1], outliers_percentage]

   # 60% data for training and 40% for testing
   X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,
                                                       random_state=random_state)

   # standardizing data for processing
   X_train_norm, X_test_norm = standardizer(X_train, X_test)

   classifiers = {'Angle-based Outlier Detector (ABOD)': ABOD(
       contamination=outliers_fraction),
       'Cluster-based Local Outlier Factor': CBLOF(
           contamination=outliers_fraction, check_estimator=False,
           random_state=random_state),
       'Feature Bagging': FeatureBagging(contamination=outliers_fraction,
                                         random_state=random_state),
       'Histogram-base Outlier Detection (HBOS)': HBOS(
           contamination=outliers_fraction),
       'Isolation Forest': IForest(contamination=outliers_fraction,
                                   random_state=random_state),
       'K Nearest Neighbors (KNN)': KNN(contamination=outliers_fraction),
       'Local Outlier Factor (LOF)': LOF(
           contamination=outliers_fraction),
       'Minimum Covariance Determinant (MCD)': MCD(
           contamination=outliers_fraction, random_state=random_state),
       'One-class SVM (OCSVM)': OCSVM(contamination=outliers_fraction),
       'Principal Component Analysis (PCA)': PCA(
           contamination=outliers_fraction, random_state=random_state),
   }

   for clf_name, clf in classifiers.items():
       t0 = time()
       clf.fit(X_train_norm)
       test_scores = clf.decision_function(X_test_norm)
       t1 = time()
       duration = round(t1 - t0, ndigits=4)
       time_list.append(duration)

       roc = round(roc_auc_score(y_test, test_scores), ndigits=4)
       prn = round(precision_n_scores(y_test, test_scores), ndigits=4)

       print('{clf_name} ROC:{roc}, precision @ rank n:{prn}, '
             'execution time: {duration}s'.format(
           clf_name=clf_name, roc=roc, prn=prn, duration=duration))

       roc_list.append(roc)
       prn_list.append(prn)

   temp_df = pd.DataFrame(time_list).transpose()
   temp_df.columns = df_columns
   time_df = pd.concat([time_df, temp_df], axis=0)

   temp_df = pd.DataFrame(roc_list).transpose()
   temp_df.columns = df_columns
   roc_df = pd.concat([roc_df, temp_df], axis=0)

   temp_df = pd.DataFrame(prn_list).transpose()
   temp_df.columns = df_columns
   prn_df = pd.concat([prn_df, temp_df], axis=0)
# Out:
# ... Processing arrhythmia.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7687, precision @ rank n:0.3571, execution time: 1.3798s
# Cluster-based Local Outlier Factor ROC:0.7684, precision @ rank n:0.4643, execution time: 1.6667s
# Feature Bagging ROC:0.7799, precision @ rank n:0.5, execution time: 0.5834s
# Histogram-base Outlier Detection (HBOS) ROC:0.8511, precision @ rank n:0.5714, execution time: 1.3975s
# Isolation Forest ROC:0.8527, precision @ rank n:0.5714, execution time: 0.3865s
# K Nearest Neighbors (KNN) ROC:0.782, precision @ rank n:0.5, execution time: 0.0878s
# Local Outlier Factor (LOF) ROC:0.7787, precision @ rank n:0.4643, execution time: 0.0758s
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinant (MCD) ROC:0.8228, precision @ rank n:0.4286, execution time: 0.6717s
# One-class SVM (OCSVM) ROC:0.7986, precision @ rank n:0.5, execution time: 0.0565s
# Principal Component Analysis (PCA) ROC:0.7997, precision @ rank n:0.5, execution time: 0.0688s
#
# ... Processing cardio.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.5763, precision @ rank n:0.1875, execution time: 0.4318s
# Cluster-based Local Outlier Factor ROC:0.8221, precision @ rank n:0.4844, execution time: 0.1666s
# Feature Bagging ROC:0.4879, precision @ rank n:0.1406, execution time: 0.7859s
# Histogram-base Outlier Detection (HBOS) ROC:0.8453, precision @ rank n:0.4688, execution time: 0.006s
# Isolation Forest ROC:0.9414, precision @ rank n:0.5, execution time: 0.4075s
# K Nearest Neighbors (KNN) ROC:0.6959, precision @ rank n:0.2812, execution time: 0.1591s
# Local Outlier Factor (LOF) ROC:0.4715, precision @ rank n:0.125, execution time: 0.0918s
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-152.770956835748848 > -250.696836140088948). You may want to try with a higher value of support_fraction (current value: 0.511).
#   RuntimeWarning)
# Minimum Covariance Determinant (MCD) ROC:0.8778, precision @ rank n:0.3906, execution time: 0.4987s
# One-class SVM (OCSVM) ROC:0.9507, precision @ rank n:0.5938, execution time: 0.1007s
# Principal Component Analysis (PCA) ROC:0.9638, precision @ rank n:0.6875, execution time: 0.004s
#
# ... Processing glass.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7104, precision @ rank n:0.25, execution time: 0.0489s
# Cluster-based Local Outlier Factor ROC:0.8506, precision @ rank n:0.25, execution time: 0.0539s
# Feature Bagging ROC:0.7043, precision @ rank n:0.25, execution time: 0.0529s
# Histogram-base Outlier Detection (HBOS) ROC:0.6524, precision @ rank n:0.0, execution time: 0.003s
# Isolation Forest ROC:0.7195, precision @ rank n:0.25, execution time: 0.3202s
# K Nearest Neighbors (KNN) ROC:0.7805, precision @ rank n:0.25, execution time: 0.01s
# Local Outlier Factor (LOF) ROC:0.7774, precision @ rank n:0.25, execution time: 0.003s
# Minimum Covariance Determinant (MCD) ROC:0.7165, precision @ rank n:0.0, execution time: 0.0389s
# One-class SVM (OCSVM) ROC:0.6189, precision @ rank n:0.25, execution time: 0.001s
# Principal Component Analysis (PCA) ROC:0.622, precision @ rank n:0.25, execution time: 0.002s
#
# ... Processing ionosphere.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9004, precision @ rank n:0.8214, execution time: 0.0873s
# Cluster-based Local Outlier Factor ROC:0.8952, precision @ rank n:0.8036, execution time: 0.0628s
# Feature Bagging ROC:0.8933, precision @ rank n:0.75, execution time: 0.0958s
# Histogram-base Outlier Detection (HBOS) ROC:0.5195, precision @ rank n:0.3393, execution time: 0.009s
# Isolation Forest ROC:0.8309, precision @ rank n:0.6607, execution time: 0.3663s
# K Nearest Neighbors (KNN) ROC:0.9134, precision @ rank n:0.8393, execution time: 0.021s
# Local Outlier Factor (LOF) ROC:0.8989, precision @ rank n:0.75, execution time: 0.007s
# Minimum Covariance Determinant (MCD) ROC:0.9399, precision @ rank n:0.8571, execution time: 0.0838s
# One-class SVM (OCSVM) ROC:0.8372, precision @ rank n:0.7143, execution time: 0.0065s
# Principal Component Analysis (PCA) ROC:0.7971, precision @ rank n:0.5893, execution time: 0.0027s
#
# ... Processing letter.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.8465, precision @ rank n:0.275, execution time: 0.4488s
# Cluster-based Local Outlier Factor ROC:0.7423, precision @ rank n:0.175, execution time: 0.1746s
# Feature Bagging ROC:0.866, precision @ rank n:0.4, execution time: 0.9214s
# Histogram-base Outlier Detection (HBOS) ROC:0.5728, precision @ rank n:0.125, execution time: 0.009s
# Isolation Forest ROC:0.5778, precision @ rank n:0.05, execution time: 0.3848s
# K Nearest Neighbors (KNN) ROC:0.845, precision @ rank n:0.3, execution time: 0.1267s
# Local Outlier Factor (LOF) ROC:0.8409, precision @ rank n:0.325, execution time: 0.0943s
# Minimum Covariance Determinant (MCD) ROC:0.7499, precision @ rank n:0.075, execution time: 1.1522s
# One-class SVM (OCSVM) ROC:0.5744, precision @ rank n:0.1, execution time: 0.0997s
# Principal Component Analysis (PCA) ROC:0.48, precision @ rank n:0.05, execution time: 0.006s
#
# ... Processing lympho.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9382, precision @ rank n:0.4, execution time: 0.0399s
# Cluster-based Local Outlier Factor ROC:0.9709, precision @ rank n:0.6, execution time: 0.0499s
# Feature Bagging ROC:0.9673, precision @ rank n:0.6, execution time: 0.0479s
# Histogram-base Outlier Detection (HBOS) ROC:0.9964, precision @ rank n:0.8, execution time: 0.0064s
# Isolation Forest ROC:0.9855, precision @ rank n:0.6, execution time: 0.3211s
# K Nearest Neighbors (KNN) ROC:0.9636, precision @ rank n:0.6, execution time: 0.006s
# Local Outlier Factor (LOF) ROC:0.9636, precision @ rank n:0.6, execution time: 0.002s
# Minimum Covariance Determinant (MCD) ROC:0.9164, precision @ rank n:0.6, execution time: 0.033s
# One-class SVM (OCSVM) ROC:0.9636, precision @ rank n:0.6, execution time: 0.001s
# Principal Component Analysis (PCA) ROC:0.9818, precision @ rank n:0.8, execution time: 0.001s
#
# ... Processing mnist.mat ...
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-303.881944356529402 > -525.830836350540153). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-304.021763033307082 > -523.143378896311901). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-338.921775030610604 > -381.672782741425522). You may want to try with a higher value of support_fraction (current value: 0.614).
#   RuntimeWarning)
# Angle-based Outlier Detector (ABOD) ROC:0.7813, precision @ rank n:0.3562, execution time: 6.2736s
# Cluster-based Local Outlier Factor ROC:0.8447, precision @ rank n:0.4007, execution time: 1.1256s
# Feature Bagging ROC:0.7259, precision @ rank n:0.3664, execution time: 58.3333s
# Histogram-base Outlier Detection (HBOS) ROC:0.5675, precision @ rank n:0.1199, execution time: 0.0758s
# Isolation Forest ROC:0.7801, precision @ rank n:0.2979, execution time: 1.7103s
# K Nearest Neighbors (KNN) ROC:0.8409, precision @ rank n:0.4144, execution time: 6.5167s
# Local Outlier Factor (LOF) ROC:0.7085, precision @ rank n:0.339, execution time: 6.1245s
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinant (MCD) ROC:0.863, precision @ rank n:0.3973, execution time: 2.6378s
# One-class SVM (OCSVM) ROC:0.8417, precision @ rank n:0.3801, execution time: 4.1369s
# Principal Component Analysis (PCA) ROC:0.8396, precision @ rank n:0.3767, execution time: 0.1106s
#
# ... Processing musk.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.0809, precision @ rank n:0.0333, execution time: 1.8516s
# Cluster-based Local Outlier Factor ROC:1.0, precision @ rank n:1.0, execution time: 0.3501s
# Feature Bagging ROC:0.5228, precision @ rank n:0.1667, execution time: 13.6278s
# Histogram-base Outlier Detection (HBOS) ROC:0.9999, precision @ rank n:0.9667, execution time: 0.0549s
# Isolation Forest ROC:0.9996, precision @ rank n:0.9333, execution time: 0.9734s
# K Nearest Neighbors (KNN) ROC:0.7348, precision @ rank n:0.2333, execution time: 1.716s
# Local Outlier Factor (LOF) ROC:0.5323, precision @ rank n:0.1333, execution time: 1.6588s
# Minimum Covariance Determinant (MCD) ROC:1.0, precision @ rank n:0.9667, execution time: 10.0665s
# One-class SVM (OCSVM) ROC:1.0, precision @ rank n:1.0, execution time: 1.1362s
# Principal Component Analysis (PCA) ROC:1.0, precision @ rank n:1.0, execution time: 0.1137s
#
# ... Processing optdigits.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.4428, precision @ rank n:0.0161, execution time: 2.416s
# Cluster-based Local Outlier Factor ROC:0.7852, precision @ rank n:0.0, execution time: 0.379s
# Feature Bagging ROC:0.4641, precision @ rank n:0.0484, execution time: 15.1759s
# Histogram-base Outlier Detection (HBOS) ROC:0.8822, precision @ rank n:0.2581, execution time: 0.0239s
# Isolation Forest ROC:0.5764, precision @ rank n:0.0161, execution time: 0.7164s
# K Nearest Neighbors (KNN) ROC:0.3824, precision @ rank n:0.0, execution time: 1.6392s
# Local Outlier Factor (LOF) ROC:0.4584, precision @ rank n:0.0484, execution time: 1.3988s
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:644: UserWarning: The covariance matrix associated to your dataset is not full rank
#   warnings.warn("The covariance matrix associated to your dataset "
# Minimum Covariance Determinant (MCD) ROC:0.3486, precision @ rank n:0.0, execution time: 1.1096s
# One-class SVM (OCSVM) ROC:0.4972, precision @ rank n:0.0, execution time: 1.4536s
# Principal Component Analysis (PCA) ROC:0.504, precision @ rank n:0.0, execution time: 0.0549s
#
# ... Processing pendigits.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.7008, precision @ rank n:0.0308, execution time: 1.5171s
# Cluster-based Local Outlier Factor ROC:0.9609, precision @ rank n:0.3077, execution time: 0.2479s
# Feature Bagging ROC:0.4687, precision @ rank n:0.0462, execution time: 3.9642s
# Histogram-base Outlier Detection (HBOS) ROC:0.9294, precision @ rank n:0.2615, execution time: 0.009s
# Isolation Forest ROC:0.9422, precision @ rank n:0.2769, execution time: 0.5545s
# K Nearest Neighbors (KNN) ROC:0.7602, precision @ rank n:0.0462, execution time: 0.4837s
# Local Outlier Factor (LOF) ROC:0.481, precision @ rank n:0.0462, execution time: 0.4672s
# Minimum Covariance Determinant (MCD) ROC:0.8271, precision @ rank n:0.0615, execution time: 1.7399s
# One-class SVM (OCSVM) ROC:0.93, precision @ rank n:0.2923, execution time: 0.8088s
# Principal Component Analysis (PCA) ROC:0.9332, precision @ rank n:0.3385, execution time: 0.006s
#
# ... Processing pima.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.6757, precision @ rank n:0.5106, execution time: 0.1516s
# Cluster-based Local Outlier Factor ROC:0.684, precision @ rank n:0.4681, execution time: 0.0738s
# Feature Bagging ROC:0.6446, precision @ rank n:0.4468, execution time: 0.0858s
# Histogram-base Outlier Detection (HBOS) ROC:0.7169, precision @ rank n:0.5213, execution time: 0.003s
# Isolation Forest ROC:0.6604, precision @ rank n:0.4787, execution time: 0.3032s
# K Nearest Neighbors (KNN) ROC:0.7252, precision @ rank n:0.5106, execution time: 0.0299s
# Local Outlier Factor (LOF) ROC:0.6604, precision @ rank n:0.4787, execution time: 0.008s
# Minimum Covariance Determinant (MCD) ROC:0.7047, precision @ rank n:0.4787, execution time: 0.0399s
# One-class SVM (OCSVM) ROC:0.6423, precision @ rank n:0.4574, execution time: 0.009s
# Principal Component Analysis (PCA) ROC:0.6639, precision @ rank n:0.5, execution time: 0.002s
#
# ... Processing satellite.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.5681, precision @ rank n:0.3918, execution time: 1.6288s
# Cluster-based Local Outlier Factor ROC:0.7234, precision @ rank n:0.5574, execution time: 0.2653s
# Feature Bagging ROC:0.557, precision @ rank n:0.4051, execution time: 6.387s
# Histogram-base Outlier Detection (HBOS) ROC:0.7393, precision @ rank n:0.5466, execution time: 0.016s
# Isolation Forest ROC:0.6843, precision @ rank n:0.5719, execution time: 0.6578s
# K Nearest Neighbors (KNN) ROC:0.6781, precision @ rank n:0.4994, execution time: 0.8423s
# Local Outlier Factor (LOF) ROC:0.5551, precision @ rank n:0.4051, execution time: 0.8687s
# Minimum Covariance Determinant (MCD) ROC:0.792, precision @ rank n:0.6747, execution time: 1.8037s
# One-class SVM (OCSVM) ROC:0.636, precision @ rank n:0.5224, execution time: 1.1505s
# Principal Component Analysis (PCA) ROC:0.5783, precision @ rank n:0.4559, execution time: 0.018s
#
# ... Processing satimage-2.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.86, precision @ rank n:0.2593, execution time: 1.7185s
# Cluster-based Local Outlier Factor ROC:0.9987, precision @ rank n:0.8889, execution time: 0.3381s
# Feature Bagging ROC:0.4971, precision @ rank n:0.0741, execution time: 5.7423s
# Histogram-base Outlier Detection (HBOS) ROC:0.9837, precision @ rank n:0.5926, execution time: 0.018s
# Isolation Forest ROC:0.9962, precision @ rank n:0.8889, execution time: 0.7031s
# K Nearest Neighbors (KNN) ROC:0.9505, precision @ rank n:0.3704, execution time: 0.7084s
# Local Outlier Factor (LOF) ROC:0.5006, precision @ rank n:0.0741, execution time: 0.7157s
# Minimum Covariance Determinant (MCD) ROC:0.9946, precision @ rank n:0.5185, execution time: 1.8047s
# One-class SVM (OCSVM) ROC:0.9976, precision @ rank n:0.9259, execution time: 1.0253s
# Principal Component Analysis (PCA) ROC:0.9841, precision @ rank n:0.8519, execution time: 0.0189s
#
# ... Processing shuttle.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.6186, precision @ rank n:0.1918, execution time: 12.9553s
# Cluster-based Local Outlier Factor ROC:0.6287, precision @ rank n:0.2336, execution time: 0.8039s
# Feature Bagging ROC:0.5211, precision @ rank n:0.111, execution time: 46.0874s
# Histogram-base Outlier Detection (HBOS) ROC:0.9851, precision @ rank n:0.9857, execution time: 0.013s
# Isolation Forest ROC:0.997, precision @ rank n:0.9308, execution time: 2.6064s
# K Nearest Neighbors (KNN) ROC:0.645, precision @ rank n:0.2199, execution time: 7.2866s
# Local Outlier Factor (LOF) ROC:0.5347, precision @ rank n:0.1406, execution time: 10.5005s
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.541490230701029 > -75.592253998160075). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.022992269210960 > -76.150022952275933). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.588090860494539 > -73.997089087121466). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.127165967938033 > -76.814431864511533). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.260339163313560 > -77.183008377260506). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.088727288180451 > -75.865165747812611). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.582785491594258 > -76.611820576922298). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.000544286938101 > -76.202702178617812). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.556584528453953 > -77.098667780846995). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.240104267009002 > -75.051128375205053). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.250211305123095 > -75.269917048873594). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.909548626708364 > -77.316510535945554). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.891326544720059 > -75.752323826887846). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.859327893628439 > -75.506059781784089). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.586488761882819 > -75.469733773072221). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.101075588075524 > -76.262519209035275). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.312636661667774 > -76.827897355973249). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.250066970764166 > -78.448260993170479). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.555505358476601 > -76.383177602584297). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.428222337190036 > -77.657757837885939). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.312868452035886 > -78.275586981066255). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.764724066883446 > -77.282352110428548). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.672481809425953 > -75.780064170775518). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.810409699568289 > -116.332661175263610). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.246740593074648 > -75.373826826201935). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.256978425484292 > -76.476983289741440). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.288199308055468 > -75.990589261846011). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.329968951469141 > -77.419260242705974). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.221834205302052 > -78.090864446968652). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.289029393101089 > -75.757556561107862). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.385618505522793 > -77.171277510572310). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.209250265997660 > -76.818840276676667). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.362224422506152 > -76.716480514242747). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.173137659451463 > -75.808458672225186). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.294483190145293 > -76.390291443926770). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.208972773367584 > -75.741530995676783). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.378081918546030 > -76.605948395137275). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.916820128958108 > -76.552623764140179). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.077545968806284 > -75.696921172394283). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.436632051329951 > -76.438541656063492). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.734734341696203 > -76.521728710156154). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.027942813065295 > -77.260538598709132). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-51.132819510101456 > -80.575229534353539). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.826679532509623 > -77.642101236679707). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# Minimum Covariance Determinant (MCD) ROC:0.9903, precision @ rank n:0.7534, execution time: 10.78s
# One-class SVM (OCSVM) ROC:0.9922, precision @ rank n:0.9553, execution time: 39.265s
# Principal Component Analysis (PCA) ROC:0.9902, precision @ rank n:0.9503, execution time: 0.0259s
#
# ... Processing shuttle.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.6227, precision @ rank n:0.1938, execution time: 14.2932s
# Cluster-based Local Outlier Factor ROC:0.6578, precision @ rank n:0.2206, execution time: 1.0278s
# Feature Bagging ROC:0.5023, precision @ rank n:0.0669, execution time: 49.2008s
# Histogram-base Outlier Detection (HBOS) ROC:0.9868, precision @ rank n:0.9386, execution time: 0.013s
# Isolation Forest ROC:0.9974, precision @ rank n:0.9486, execution time: 2.4205s
# K Nearest Neighbors (KNN) ROC:0.6549, precision @ rank n:0.2213, execution time: 7.4483s
# Local Outlier Factor (LOF) ROC:0.5336, precision @ rank n:0.155, execution time: 10.0081s
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.425442543000088 > -74.297176435073879). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.564705869881607 > -75.449647848888659). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.052965351125650 > -77.873043502795170). You may want to try with a higher value of support_fraction (current value: 0.503).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.711637596421809 > -77.918467116365463). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.288408206379785 > -76.047930269374291). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.163987962567269 > -75.094540425331587). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.135758497968666 > -75.386723544152801). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.034804702891627 > -77.013439034162033). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.898066030900893 > -74.945008296693317). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.743045566606355 > -76.543953649148818). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.161939714444387 > -77.718987832818939). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.449721409434375 > -77.463350997929240). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.484729520550523 > -77.209408075339610). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.530855052079332 > -75.986925295027177). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.537671108475173 > -76.516863516247341). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.119894415936592 > -74.750171660213454). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.132421426890048 > -78.065531331553387). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.689479782368572 > -76.516189003841816). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.526174623542239 > -76.929259893504295). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.676926199554828 > -77.078739390008721). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.079613405598963 > -78.068675160155834). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.079613405598963 > -75.055300208529331). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.175067559265059 > -75.501850740725189). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.209712367844574 > -75.753423107295433). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.575087107748168 > -78.226041949655098). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.493363258255101 > -75.585858300834488). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.872791578404886 > -81.239909999570003). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.133797032016744 > -76.364589262170597). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.527100113121982 > -75.456920641800551). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.323484101477526 > -76.567667705597188). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.490035891429635 > -75.732589191544065). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.544188199759390 > -75.515220980584928). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.245604097561603 > -75.406373240982191). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.317846417311827 > -76.031468921189557). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.496115152758847 > -76.126788040540973). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.519042778223508 > -74.607053202382104). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.565732801173368 > -75.429741429983963). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.572689117846402 > -75.573224838260089). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.403637063389461 > -78.361278455029208). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.089686266632278 > -76.295185566653032). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.585711188387776 > -76.596539635210377). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.693102363118065 > -76.074198371033219). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.549097982809606 > -76.196773254233463). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.195295682887185 > -76.818426165090898). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.235586690628807 > -75.502402815830663). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.479380672561469 > -76.095613477988124). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.720526178777050 > -76.019977745163871). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.647885023337921 > -79.199187806199220). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.516473309200578 > -76.576896245204409). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.372183158708737 > -76.358625403912711). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.835499092286717 > -74.606867107292089). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.863734370680120 > -75.395146477137999). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-48.807030513252769 > -76.759853309338808). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.310973294211813 > -77.475624485199546). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.360104041486224 > -76.826591355527967). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.187085480983299 > -79.103461765502885). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.638815184141905 > -75.685612074623720). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.260318243724626 > -78.203371189667024). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.721571555886165 > -77.525477082064413). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.750174634086775 > -76.209331082488589). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-49.534919108837677 > -75.845168773515738). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# C:\Users\Komal\anaconda3\lib\site-packages\sklearn\covariance\_robust_covariance.py:170: RuntimeWarning: Determinant has increased; this should not happen: log(det) > log(previous_det) (-50.135518820851445 > -77.979972832954047). You may want to try with a higher value of support_fraction (current value: 0.501).
#   RuntimeWarning)
# Minimum Covariance Determinant (MCD) ROC:0.9897, precision @ rank n:0.7477, execution time: 10.3174s
# One-class SVM (OCSVM) ROC:0.9923, precision @ rank n:0.9605, execution time: 39.0932s
# Principal Component Analysis (PCA) ROC:0.9907, precision @ rank n:0.9577, execution time: 0.0249s
#
# ... Processing vertebral.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.3688, precision @ rank n:0.0, execution time: 0.0399s
# Cluster-based Local Outlier Factor ROC:0.3891, precision @ rank n:0.0, execution time: 0.0489s
# Feature Bagging ROC:0.3688, precision @ rank n:0.0, execution time: 0.0349s
# Histogram-base Outlier Detection (HBOS) ROC:0.3617, precision @ rank n:0.0, execution time: 0.003s
# Isolation Forest ROC:0.3539, precision @ rank n:0.0, execution time: 0.2633s
# K Nearest Neighbors (KNN) ROC:0.3562, precision @ rank n:0.0, execution time: 0.0085s
# Local Outlier Factor (LOF) ROC:0.3562, precision @ rank n:0.0, execution time: 0.002s
# Minimum Covariance Determinant (MCD) ROC:0.4203, precision @ rank n:0.0, execution time: 0.0429s
# One-class SVM (OCSVM) ROC:0.4078, precision @ rank n:0.0, execution time: 0.002s
# Principal Component Analysis (PCA) ROC:0.3633, precision @ rank n:0.0625, execution time: 0.002s
#
# ... Processing vowels.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.8982, precision @ rank n:0.2857, execution time: 0.2543s
# Cluster-based Local Outlier Factor ROC:0.8608, precision @ rank n:0.2143, execution time: 0.0788s
# Feature Bagging ROC:0.9124, precision @ rank n:0.2143, execution time: 0.3062s
# Histogram-base Outlier Detection (HBOS) ROC:0.7567, precision @ rank n:0.2143, execution time: 0.003s
# Isolation Forest ROC:0.8141, precision @ rank n:0.1429, execution time: 0.3227s
# K Nearest Neighbors (KNN) ROC:0.9746, precision @ rank n:0.3571, execution time: 0.0598s
# Local Outlier Factor (LOF) ROC:0.9192, precision @ rank n:0.2857, execution time: 0.0289s
# Minimum Covariance Determinant (MCD) ROC:0.6966, precision @ rank n:0.0714, execution time: 0.6832s
# One-class SVM (OCSVM) ROC:0.8426, precision @ rank n:0.2857, execution time: 0.0379s
# Principal Component Analysis (PCA) ROC:0.6907, precision @ rank n:0.2143, execution time: 0.002s
#
# ... Processing wbc.mat ...
# Angle-based Outlier Detector (ABOD) ROC:0.9573, precision @ rank n:0.5556, execution time: 0.0788s
# Cluster-based Local Outlier Factor ROC:0.9751, precision @ rank n:0.6667, execution time: 0.0618s
# Feature Bagging ROC:0.979, precision @ rank n:0.7778, execution time: 0.0908s
# Histogram-base Outlier Detection (HBOS) ROC:0.9876, precision @ rank n:0.6667, execution time: 0.007s
# Isolation Forest ROC:0.9674, precision @ rank n:0.5556, execution time: 0.3057s
# K Nearest Neighbors (KNN) ROC:0.9713, precision @ rank n:0.4444, execution time: 0.016s
# Local Outlier Factor (LOF) ROC:0.979, precision @ rank n:0.6667, execution time: 0.006s
# Minimum Covariance Determinant (MCD) ROC:0.9658, precision @ rank n:0.5556, execution time: 0.0598s
# One-class SVM (OCSVM) ROC:0.9782, precision @ rank n:0.6667, execution time: 0.006s
# Principal Component Analysis (PCA) ROC:0.9775, precision @ rank n:0.6667, execution time: 0.002s

# %%
roc_df
# Out:
#          Data #Sample #Dimensions Outlier Perc     PCA     MCD   OCSVM  \
# 0  arrhythmia     452         274      14.6018  0.7687  0.7684  0.7799
# 0      cardio    1831          21       9.6122  0.5763  0.8221  0.4879
# 0       glass     214           9       4.2056  0.7104  0.8506  0.7043
# 0  ionosphere     351          33      35.8974  0.9004  0.8952  0.8933
# 0      letter    1600          32         6.25  0.8465  0.7423   0.866
# 0      lympho     148          18       4.0541  0.9382  0.9709  0.9673
# 0       mnist    7603         100       9.2069  0.7813  0.8447  0.7259
# 0        musk    3062         166       3.1679  0.0809       1  0.5228
# 0   optdigits    5216          64       2.8758  0.4428  0.7852  0.4641
# 0   pendigits    6870          16       2.2707  0.7008  0.9609  0.4687
# 0        pima     768           8      34.8958  0.6757   0.684  0.6446
# 0   satellite    6435          36      31.6395  0.5681  0.7234   0.557
# 0  satimage-2    5803          36       1.2235    0.86  0.9987  0.4971
# 0     shuttle   49097           9       7.1511  0.6186  0.6287  0.5211
# 0     shuttle   49097           9       7.1511  0.6227  0.6578  0.5023
# 0   vertebral     240           6         12.5  0.3688  0.3891  0.3688
# 0      vowels    1456          12       3.4341  0.8982  0.8608  0.9124
# 0         wbc     378          30       5.5556  0.9573  0.9751   0.979
#
#       LOF   CBLOF     KNN    HBOS    ABOD IFOREST FEATUREBAGGING
# 0  0.8511  0.8527   0.782  0.7787  0.8228  0.7986         0.7997
# 0  0.8453  0.9414  0.6959  0.4715  0.8778  0.9507         0.9638
# 0  0.6524  0.7195  0.7805  0.7774  0.7165  0.6189          0.622
# 0  0.5195  0.8309  0.9134  0.8989  0.9399  0.8372         0.7971
# 0  0.5728  0.5778   0.845  0.8409  0.7499  0.5744           0.48
# 0  0.9964  0.9855  0.9636  0.9636  0.9164  0.9636         0.9818
# 0  0.5675  0.7801  0.8409  0.7085   0.863  0.8417         0.8396
# 0  0.9999  0.9996  0.7348  0.5323       1       1              1
# 0  0.8822  0.5764  0.3824  0.4584  0.3486  0.4972          0.504
# 0  0.9294  0.9422  0.7602   0.481  0.8271    0.93         0.9332
# 0  0.7169  0.6604  0.7252  0.6604  0.7047  0.6423         0.6639
# 0  0.7393  0.6843  0.6781  0.5551   0.792   0.636         0.5783
# 0  0.9837  0.9962  0.9505  0.5006  0.9946  0.9976         0.9841
# 0  0.9851   0.997   0.645  0.5347  0.9903  0.9922         0.9902
# 0  0.9868  0.9974  0.6549  0.5336  0.9897  0.9923         0.9907
# 0  0.3617  0.3539  0.3562  0.3562  0.4203  0.4078         0.3633
# 0  0.7567  0.8141  0.9746  0.9192  0.6966  0.8426         0.6907
# 0  0.9876  0.9674  0.9713   0.979  0.9658  0.9782         0.9775

# %%
prn_df
# Out:
#          Data #Sample #Dimensions Outlier Perc     PCA     MCD   OCSVM  \
# 0  arrhythmia     452         274      14.6018  0.3571  0.4643     0.5
# 0      cardio    1831          21       9.6122  0.1875  0.4844  0.1406
# 0       glass     214           9       4.2056    0.25    0.25    0.25
# 0  ionosphere     351          33      35.8974  0.8214  0.8036    0.75
# 0      letter    1600          32         6.25   0.275   0.175     0.4
# 0      lympho     148          18       4.0541     0.4     0.6     0.6
# 0       mnist    7603         100       9.2069  0.3562  0.4007  0.3664
# 0        musk    3062         166       3.1679  0.0333       1  0.1667
# 0   optdigits    5216          64       2.8758  0.0161       0  0.0484
# 0   pendigits    6870          16       2.2707  0.0308  0.3077  0.0462
# 0        pima     768           8      34.8958  0.5106  0.4681  0.4468
# 0   satellite    6435          36      31.6395  0.3918  0.5574  0.4051
# 0  satimage-2    5803          36       1.2235  0.2593  0.8889  0.0741
# 0     shuttle   49097           9       7.1511  0.1918  0.2336   0.111
# 0     shuttle   49097           9       7.1511  0.1938  0.2206  0.0669
# 0   vertebral     240           6         12.5       0       0       0
# 0      vowels    1456          12       3.4341  0.2857  0.2143  0.2143
# 0         wbc     378          30       5.5556  0.5556  0.6667  0.7778
#
#       LOF   CBLOF     KNN    HBOS    ABOD IFOREST FEATUREBAGGING
# 0  0.5714  0.5714     0.5  0.4643  0.4286     0.5            0.5
# 0  0.4688     0.5  0.2812   0.125  0.3906  0.5938         0.6875
# 0       0    0.25    0.25    0.25       0    0.25           0.25
# 0  0.3393  0.6607  0.8393    0.75  0.8571  0.7143         0.5893
# 0   0.125    0.05     0.3   0.325   0.075     0.1           0.05
# 0     0.8     0.6     0.6     0.6     0.6     0.6            0.8
# 0  0.1199  0.2979  0.4144   0.339  0.3973  0.3801         0.3767
# 0  0.9667  0.9333  0.2333  0.1333  0.9667       1              1
# 0  0.2581  0.0161       0  0.0484       0       0              0
# 0  0.2615  0.2769  0.0462  0.0462  0.0615  0.2923         0.3385
# 0  0.5213  0.4787  0.5106  0.4787  0.4787  0.4574            0.5
# 0  0.5466  0.5719  0.4994  0.4051  0.6747  0.5224         0.4559
# 0  0.5926  0.8889  0.3704  0.0741  0.5185  0.9259         0.8519
# 0  0.9857  0.9308  0.2199  0.1406  0.7534  0.9553         0.9503
# 0  0.9386  0.9486  0.2213   0.155  0.7477  0.9605         0.9577
# 0       0       0       0       0       0       0         0.0625
# 0  0.2143  0.1429  0.3571  0.2857  0.0714  0.2857         0.2143
# 0  0.6667  0.5556  0.4444  0.6667  0.5556  0.6667         0.6667

# %%
time_df
# Out:
#          Data #Sample #Dimensions Outlier Perc      PCA     MCD    OCSVM  \
# 0  arrhythmia     452         274      14.6018   1.3798  1.6667   0.5834
# 0      cardio    1831          21       9.6122   0.4318  0.1666   0.7859
# 0       glass     214           9       4.2056   0.0489  0.0539   0.0529
# 0  ionosphere     351          33      35.8974   0.0873  0.0628   0.0958
# 0      letter    1600          32         6.25   0.4488  0.1746   0.9214
# 0      lympho     148          18       4.0541   0.0399  0.0499   0.0479
# 0       mnist    7603         100       9.2069   6.2736  1.1256  58.3333
# 0        musk    3062         166       3.1679   1.8516  0.3501  13.6278
# 0   optdigits    5216          64       2.8758    2.416   0.379  15.1759
# 0   pendigits    6870          16       2.2707   1.5171  0.2479   3.9642
# 0        pima     768           8      34.8958   0.1516  0.0738   0.0858
# 0   satellite    6435          36      31.6395   1.6288  0.2653    6.387
# 0  satimage-2    5803          36       1.2235   1.7185  0.3381   5.7423
# 0     shuttle   49097           9       7.1511  12.9553  0.8039  46.0874
# 0     shuttle   49097           9       7.1511  14.2932  1.0278  49.2008
# 0   vertebral     240           6         12.5   0.0399  0.0489   0.0349
# 0      vowels    1456          12       3.4341   0.2543  0.0788   0.3062
# 0         wbc     378          30       5.5556   0.0788  0.0618   0.0908
#
#       LOF   CBLOF     KNN     HBOS     ABOD  IFOREST FEATUREBAGGING
# 0  1.3975  0.3865  0.0878   0.0758   0.6717   0.0565         0.0688
# 0   0.006  0.4075  0.1591   0.0918   0.4987   0.1007          0.004
# 0   0.003  0.3202    0.01    0.003   0.0389    0.001          0.002
# 0   0.009  0.3663   0.021    0.007   0.0838   0.0065         0.0027
# 0   0.009  0.3848  0.1267   0.0943   1.1522   0.0997          0.006
# 0  0.0064  0.3211   0.006    0.002    0.033    0.001          0.001
# 0  0.0758  1.7103  6.5167   6.1245   2.6378   4.1369         0.1106
# 0  0.0549  0.9734   1.716   1.6588  10.0665   1.1362         0.1137
# 0  0.0239  0.7164  1.6392   1.3988   1.1096   1.4536         0.0549
# 0   0.009  0.5545  0.4837   0.4672   1.7399   0.8088          0.006
# 0   0.003  0.3032  0.0299    0.008   0.0399    0.009          0.002
# 0   0.016  0.6578  0.8423   0.8687   1.8037   1.1505          0.018
# 0   0.018  0.7031  0.7084   0.7157   1.8047   1.0253         0.0189
# 0   0.013  2.6064  7.2866  10.5005    10.78   39.265         0.0259
# 0   0.013  2.4205  7.4483  10.0081  10.3174  39.0932         0.0249
# 0   0.003  0.2633  0.0085    0.002   0.0429    0.002          0.002
# 0   0.003  0.3227  0.0598   0.0289   0.6832   0.0379          0.002
# 0   0.007  0.3057   0.016    0.006   0.0598    0.006          0.002
